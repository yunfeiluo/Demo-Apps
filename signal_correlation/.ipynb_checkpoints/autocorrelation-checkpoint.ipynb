# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
# Helper Functions
def plot_signal(signal, xl='x-axis', yl='y-axis', title=''):
    plt.plot(signal)
    plt.title(title)
    plt.xlabel(xl)
    plt.ylabel(yl)
    plt.show()

def plot_2(sig1, sig2, xl='x-axis', yl='y-axis', title='', subtitle1='', subtitle2=''):
    fig, axs = plt.subplots(2, 1)
    fig.tight_layout(pad=5.0)
    fig.suptitle(title)
    axs[0].plot(sig1)
    axs[0].set_title(subtitle1)
    axs[0].set_xlabel(xl)
    axs[0].set_ylabel(yl)
    
    axs[1].plot(sig2)
    axs[1].set_title(subtitle2)
    axs[1].set_xlabel(xl)
    axs[1].set_ylabel(yl)
    
    plt.show()
    
def get_spec(x, sampling_rate, verbose=False):
    fft_size = len(x)
#     xf = np.fft.rfft(x)
    xf = np.fft.fft(x)[:fft_size//2]
    freqs = np.linspace(0, sampling_rate//2, int((fft_size/2) + 0.5))
    xfp = np.abs(xf) / fft_size # 幅度
    xfxw = np.angle(xf) # 相位
    
    WIDTH_SIZE, HEIGHT_SIZE = 20, 6
    if verbose:
        # 原图
        plt.figure(figsize=(WIDTH_SIZE,HEIGHT_SIZE))
        plt.plot(x)
        plt.title("Original Signal")
        plt.xlabel("Time Steps")
        plt.ylabel("Signal")
        plt.show()

        # 幅度谱
        plt.figure(figsize=(WIDTH_SIZE,HEIGHT_SIZE))
        plt.plot(freqs, xfp)
        plt.title("Amplitude Spectrum")
        plt.xlabel("Frequency")
        plt.ylabel("Abs")
        plt.show()

        # 相位谱
        plt.figure(figsize=(WIDTH_SIZE,HEIGHT_SIZE))
        plt.plot(freqs, xfxw)
        plt.title("Phase Spectrum")
        plt.xlabel("Frequency")
        plt.ylabel("Angle")
        plt.show()
        
    return freqs, xfp, xfxw # 频率，幅度，相位

# Main Algorithms
def linear_corr(sig1, sig2, mode='full'):
    nom = np.linalg.norm(sig1[:])*np.linalg.norm(sig2[:])
    corr = np.correlate(sig1, sig2, mode=mode)/nom
    return corr

def circular_corr(sig1, sig2): 
    # sig1 and sig2 must have same length
    nom = np.linalg.norm(sig1[:])*np.linalg.norm(sig2[:])
    return np.fft.irfft(np.fft.rfft(sig1)*np.fft.rfft(sig2[::-1]))/nom

def same_len_corr(sig1, sig2, sampling_rate):
    corr = circular_corr(sig1, sig2)
    return corr
                                                           
def search_corr(sig1, sig2, sampling_rate):
    # search sig1 over sig2
    corr = linear_corr(sig1, sig2, mode='same')
    return corr

# %% [markdown]
# # 计算相关性

# %%
sampling_rate = 128
range_ = np.arange(0, 2, 1/sampling_rate)

# First signal 
sig1_f = lambda t: 100 * np.sin(2 * np.pi * t)
sig1 = sig1_f(range_)

# Seconds signal with pi/4 phase shift. Half the size of sig1
sig2_f = lambda t: 3 * np.sin(2 * np.pi * t) + 2 * np.sin(4 * np.pi * t)
sig2 = sig2_f(range_)
# sig2 = sig1
# sig1 = sig2

# Circular Correlation
corr_cir = same_len_corr(sig1, sig2, sampling_rate)

# Linear Correlation
corr_linear = search_corr(sig1, sig2, sampling_rate)

# verbose
print("Max Circular Correlation:", max(np.abs(corr_cir)))
print("Max Linear Correlation:", max(np.abs(corr_linear)))

plot_2(sig1, sig2, xl='time_step', yl='signal', title='Original Signals', subtitle1='Singal 1', subtitle2='Singal 2')
plot_2(
    corr_cir, 
    corr_linear, 
    xl='time_step', 
    yl='Corr Coeffs', 
    title='Coorelations', 
    subtitle1='Circular Correlation', 
    subtitle2='Linear Correlation'
)
# Out:
# Max Circular Correlation: 0.8320502943378438
# Max Linear Correlation: 0.8320502943378437

# %% [markdown]
# # 计算频谱

# %%
# Synthetic data
sampling_rate = 128
range_ = np.arange(0, 3, 1/sampling_rate)
print("Sampling rate:", sampling_rate)
print("Number of Points:", len(range_))

sig_f = lambda t: 100 * np.sin(2 * np.pi * t)
sig = sig_f(range_)

f1, sig_a, sig_p = get_spec(sig, sampling_rate, verbose=True)
# Out:
# Sampling rate: 128
# Number of Points: 384
